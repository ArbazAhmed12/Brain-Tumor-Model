# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-907070862.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# !pip install -q kaggle nibabel tqdm matplotlib numpy

# %%
from google.colab import files
files.upload()   # upload kaggle.json here
# Out:
#      <input type="file" id="files-dd3581f9-bc7b-4ed4-946c-d390cd3f9e8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd3581f9-bc7b-4ed4-946c-d390cd3f9e8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.makedirs("/root/.kaggle", exist_ok=True)
# !cp kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# Create dataset directory in Drive
DATASET_DIR = "/content/drive/MyDrive/Major_project/brats"
os.makedirs(DATASET_DIR, exist_ok=True)

# Download dataset
# !kaggle datasets download -d awsaf49/brats2020-training-data -p {DATASET_DIR}
# Out:
# Dataset URL: https://www.kaggle.com/datasets/awsaf49/brats2020-training-data
# License(s): CC0-1.0
# ^C

# %%
import os

print("Files in dataset directory:")
print(os.listdir(DATASET_DIR))
# Out:
# Files in dataset directory:
# []

# %%
# !kaggle datasets download -d mateuszbuda/lgg-mri-segmentation -p {DATASET_DIR}
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation
# License(s): CC-BY-NC-SA-4.0
# ...
#  99% 708M/714M [00:04<00:00, 158MB/s]
# 100% 714M/714M [00:04<00:00, 173MB/s]

# %%
print(os.listdir(DATASET_DIR))
# Out:
# ['lgg-mri-segmentation.zip']

# %%
import zipfile
import os

zip_files = [f for f in os.listdir(DATASET_DIR) if f.endswith(".zip")]
print("ZIP files found:", zip_files)

zip_path = os.path.join(DATASET_DIR, zip_files[0])

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(DATASET_DIR)

print("✅ Dataset extracted successfully")
# Out:
# ZIP files found: ['lgg-mri-segmentation.zip']
# ✅ Dataset extracted successfully

# %%
print(os.listdir(DATASET_DIR))
# Out:
# ['lgg-mri-segmentation.zip', 'kaggle_3m', 'lgg-mri-segmentation']
